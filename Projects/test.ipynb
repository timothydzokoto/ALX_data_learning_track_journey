# %%
import joblib
import pandas as pd

# ── Check model ─────────────────────────────────────────────
model = joblib.load(r'C:\Users\Tim\Documents\DS_Course\Projects\models\titanic_survival_model.pkl')
print("Model type:", type(model).__name__)
print("Model details:", model)

# ── Check dataset ───────────────────────────────────────────
df = pd.read_csv(r'C:\Users\Tim\Documents\DS_Course\Projects\titanic.csv')
print("\nDataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nFirst 3 rows:")
print(df.head(3))

# ── Check what features the model expects ──────────────────
if hasattr(model, 'feature_names_in_'):
    print("\nModel expects these features:")
    print(model.feature_names_in_)
elif hasattr(model, 'n_features_in_'):
    print("\nNumber of features model expects:", model.n_features_in_)
# Out:
# Model type: RandomForestClassifier
# Model details: RandomForestClassifier(min_samples_split=10, n_estimators=200, random_state=42)
#
# Dataset shape: (891, 12)
# Columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# First 3 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#
# ...
