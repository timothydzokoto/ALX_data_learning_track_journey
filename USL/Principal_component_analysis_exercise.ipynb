# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Exercise.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>
#
# # Exercise: Principal component analysis
# © ExploreAI Academy
#
# In this exercise, we apply PCA to a dataset, evaluate the cumulative variance explained, and determine the appropriate number of components to retain.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should be able to:
# * Apply PCA to reduce a dataset’s dimensionality.
# * Evaluate the cumulative variance explained by each principal component.
# * Determine the number of components needed to capture at least 85% of the variance.

# %% [markdown]
# ## Overview
#
# The Digits dataset consists of 1,797 images of handwritten digits, each represented by a 64-dimensional feature vector. The dataset's high dimensionality can pose challenges when visualising and exploring it and could also lead to model complexity.
#
# In this exercise, we apply PCA to the Digits dataset and evaluate its ability to reduce the dataset's dimensionality while retaining valuable information.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load and prepare dataset

# %%
# Load the dataset
digits = load_digits()
X = digits.data
y = digits.target

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# To reduce the dataset's dimensionality, let's transform the standardised dataset by applying PCA.

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# ### Exercise 2
#
# To understand which components carry the most information, we can assess how much of the dataset's variance is captured by each principal component.
#
# Compute and print the `Explained Variance Ratio` for each principal component formatted to four decimal places.

# %%
# Compute the explained variance ratio and print each pca formatted to 4 decimal places
explained_variance_ratio = pca.explained_variance_ratio_

# Print the explained variance ratio
for i, ratio in enumerate(explained_variance_ratio):
    print(f"Principal Component {i + 1}: Explained Variance Ratio = {ratio:.4f}")
# Out:
# Principal Component 1: Explained Variance Ratio = 0.1203
# Principal Component 2: Explained Variance Ratio = 0.0956
# Principal Component 3: Explained Variance Ratio = 0.0844
# Principal Component 4: Explained Variance Ratio = 0.0650
# Principal Component 5: Explained Variance Ratio = 0.0486
# Principal Component 6: Explained Variance Ratio = 0.0421
# Principal Component 7: Explained Variance Ratio = 0.0394
# Principal Component 8: Explained Variance Ratio = 0.0339
# Principal Component 9: Explained Variance Ratio = 0.0300
# Principal Component 10: Explained Variance Ratio = 0.0293
# Principal Component 11: Explained Variance Ratio = 0.0278
# Principal Component 12: Explained Variance Ratio = 0.0258
# Principal Component 13: Explained Variance Ratio = 0.0228
# Principal Component 14: Explained Variance Ratio = 0.0223
# Principal Component 15: Explained Variance Ratio = 0.0217
# Principal Component 16: Explained Variance Ratio = 0.0191
# Principal Component 17: Explained Variance Ratio = 0.0178
# Principal Component 18: Explained Variance Ratio = 0.0164
# Principal Component 19: Explained Variance Ratio = 0.0160
# Principal Component 20: Explained Variance Ratio = 0.0149
# Principal Component 21: Explained Variance Ratio = 0.0135
# Principal Component 22: Explained Variance Ratio = 0.0127
# Principal Component 23: Explained Variance Ratio = 0.0117
# Principal Component 24: Explained Variance Ratio = 0.0106
# Principal Component 25: Explained Variance Ratio = 0.0098
# Principal Component 26: Explained Variance Ratio = 0.0094
# Principal Component 27: Explained Variance Ratio = 0.0086
# Principal Component 28: Explained Variance Ratio = 0.0084
# Principal Component 29: Explained Variance Ratio = 0.0080
# Principal Component 30: Explained Variance Ratio = 0.0075
# Principal Component 31: Explained Variance Ratio = 0.0073
# Principal Component 32: Explained Variance Ratio = 0.0069
# Principal Component 33: Explained Variance Ratio = 0.0065
# Principal Component 34: Explained Variance Ratio = 0.0064
# Principal Component 35: Explained Variance Ratio = 0.0059
# Principal Component 36: Explained Variance Ratio = 0.0057
# Principal Component 37: Explained Variance Ratio = 0.0052
# Principal Component 38: Explained Variance Ratio = 0.0048
# Principal Component 39: Explained Variance Ratio = 0.0045
# Principal Component 40: Explained Variance Ratio = 0.0042
# Principal Component 41: Explained Variance Ratio = 0.0041
# Principal Component 42: Explained Variance Ratio = 0.0040
# Principal Component 43: Explained Variance Ratio = 0.0036
# Principal Component 44: Explained Variance Ratio = 0.0034
# Principal Component 45: Explained Variance Ratio = 0.0033
# Principal Component 46: Explained Variance Ratio = 0.0031
# Principal Component 47: Explained Variance Ratio = 0.0029
# Principal Component 48: Explained Variance Ratio = 0.0028
# Principal Component 49: Explained Variance Ratio = 0.0026
# Principal Component 50: Explained Variance Ratio = 0.0023
# Principal Component 51: Explained Variance Ratio = 0.0022
# Principal Component 52: Explained Variance Ratio = 0.0020
# Principal Component 53: Explained Variance Ratio = 0.0020
# Principal Component 54: Explained Variance Ratio = 0.0018
# Principal Component 55: Explained Variance Ratio = 0.0017
# Principal Component 56: Explained Variance Ratio = 0.0016
# Principal Component 57: Explained Variance Ratio = 0.0015
# Principal Component 58: Explained Variance Ratio = 0.0014
# Principal Component 59: Explained Variance Ratio = 0.0013
# Principal Component 60: Explained Variance Ratio = 0.0010
# Principal Component 61: Explained Variance Ratio = 0.0008
# Principal Component 62: Explained Variance Ratio = 0.0000
# Principal Component 63: Explained Variance Ratio = 0.0000
# Principal Component 64: Explained Variance Ratio = 0.0000

# %% [markdown]
# ### Exercise 3
#
# We can also evaluate how much total variance is captured as components are added incrementally. This can help us get a view of how many components are needed to capture a substantial proportion of the dataset's variance.
#
# Determine the cumulative variance ratio by summing the explained variance ratios of each principal component.

# %%
# Determine the cumulative variance ratio by summing the explained variance ratio
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)
for i, cumulative_ratio in enumerate(cumulative_variance_ratio):
    print(f"Cumulative Variance Ratio up to Principal Component {i + 1}: {cumulative_ratio:.4f}")
# Out:
# Cumulative Variance Ratio up to Principal Component 1: 0.1203
# Cumulative Variance Ratio up to Principal Component 2: 0.2159
# Cumulative Variance Ratio up to Principal Component 3: 0.3004
# Cumulative Variance Ratio up to Principal Component 4: 0.3654
# Cumulative Variance Ratio up to Principal Component 5: 0.4140
# Cumulative Variance Ratio up to Principal Component 6: 0.4561
# Cumulative Variance Ratio up to Principal Component 7: 0.4955
# Cumulative Variance Ratio up to Principal Component 8: 0.5294
# Cumulative Variance Ratio up to Principal Component 9: 0.5594
# Cumulative Variance Ratio up to Principal Component 10: 0.5887
# Cumulative Variance Ratio up to Principal Component 11: 0.6166
# Cumulative Variance Ratio up to Principal Component 12: 0.6423
# Cumulative Variance Ratio up to Principal Component 13: 0.6651
# Cumulative Variance Ratio up to Principal Component 14: 0.6874
# Cumulative Variance Ratio up to Principal Component 15: 0.7090
# Cumulative Variance Ratio up to Principal Component 16: 0.7281
# Cumulative Variance Ratio up to Principal Component 17: 0.7459
# Cumulative Variance Ratio up to Principal Component 18: 0.7623
# Cumulative Variance Ratio up to Principal Component 19: 0.7782
# Cumulative Variance Ratio up to Principal Component 20: 0.7931
# Cumulative Variance Ratio up to Principal Component 21: 0.8066
# Cumulative Variance Ratio up to Principal Component 22: 0.8193
# Cumulative Variance Ratio up to Principal Component 23: 0.8310
# Cumulative Variance Ratio up to Principal Component 24: 0.8416
# Cumulative Variance Ratio up to Principal Component 25: 0.8513
# Cumulative Variance Ratio up to Principal Component 26: 0.8608
# Cumulative Variance Ratio up to Principal Component 27: 0.8694
# Cumulative Variance Ratio up to Principal Component 28: 0.8778
# Cumulative Variance Ratio up to Principal Component 29: 0.8857
# Cumulative Variance Ratio up to Principal Component 30: 0.8932
# Cumulative Variance Ratio up to Principal Component 31: 0.9005
# Cumulative Variance Ratio up to Principal Component 32: 0.9074
# Cumulative Variance Ratio up to Principal Component 33: 0.9139
# Cumulative Variance Ratio up to Principal Component 34: 0.9203
# Cumulative Variance Ratio up to Principal Component 35: 0.9262
# Cumulative Variance Ratio up to Principal Component 36: 0.9320
# Cumulative Variance Ratio up to Principal Component 37: 0.9372
# Cumulative Variance Ratio up to Principal Component 38: 0.9420
# Cumulative Variance Ratio up to Principal Component 39: 0.9465
# Cumulative Variance Ratio up to Principal Component 40: 0.9508
# Cumulative Variance Ratio up to Principal Component 41: 0.9548
# Cumulative Variance Ratio up to Principal Component 42: 0.9588
# Cumulative Variance Ratio up to Principal Component 43: 0.9624
# Cumulative Variance Ratio up to Principal Component 44: 0.9658
# Cumulative Variance Ratio up to Principal Component 45: 0.9691
# Cumulative Variance Ratio up to Principal Component 46: 0.9722
# Cumulative Variance Ratio up to Principal Component 47: 0.9751
# Cumulative Variance Ratio up to Principal Component 48: 0.9778
# Cumulative Variance Ratio up to Principal Component 49: 0.9804
# Cumulative Variance Ratio up to Principal Component 50: 0.9828
# Cumulative Variance Ratio up to Principal Component 51: 0.9849
# Cumulative Variance Ratio up to Principal Component 52: 0.9870
# Cumulative Variance Ratio up to Principal Component 53: 0.9889
# Cumulative Variance Ratio up to Principal Component 54: 0.9908
# Cumulative Variance Ratio up to Principal Component 55: 0.9924
# Cumulative Variance Ratio up to Principal Component 56: 0.9941
# Cumulative Variance Ratio up to Principal Component 57: 0.9955
# Cumulative Variance Ratio up to Principal Component 58: 0.9969
# Cumulative Variance Ratio up to Principal Component 59: 0.9981
# Cumulative Variance Ratio up to Principal Component 60: 0.9992
# Cumulative Variance Ratio up to Principal Component 61: 1.0000
# Cumulative Variance Ratio up to Principal Component 62: 1.0000
# Cumulative Variance Ratio up to Principal Component 63: 1.0000
# Cumulative Variance Ratio up to Principal Component 64: 1.0000

# %% [markdown]
# ### Exercise 4
#
# Based on the results from **Exercise 3**, determine how many components are needed to capture at least 85% of the total variance.
#
# Discuss the impact of this on subsequent analysis or modeling.

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# ### Exercise 2

# %%
# Get the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print the explained variance ratio
for i, ev in enumerate(explained_variance_ratio):
    print(f"PC{i+1}: Explained Variance = {ev:.4f}")
# Out:
# PC1: Explained Variance = 0.1203
# PC2: Explained Variance = 0.0956
# PC3: Explained Variance = 0.0844
# PC4: Explained Variance = 0.0650
# PC5: Explained Variance = 0.0486
# PC6: Explained Variance = 0.0421
# PC7: Explained Variance = 0.0394
# PC8: Explained Variance = 0.0339
# PC9: Explained Variance = 0.0300
# PC10: Explained Variance = 0.0293
# PC11: Explained Variance = 0.0278
# PC12: Explained Variance = 0.0258
# PC13: Explained Variance = 0.0228
# PC14: Explained Variance = 0.0223
# PC15: Explained Variance = 0.0217
# PC16: Explained Variance = 0.0191
# PC17: Explained Variance = 0.0178
# PC18: Explained Variance = 0.0164
# PC19: Explained Variance = 0.0160
# PC20: Explained Variance = 0.0149
# PC21: Explained Variance = 0.0135
# PC22: Explained Variance = 0.0127
# PC23: Explained Variance = 0.0117
# PC24: Explained Variance = 0.0106
# PC25: Explained Variance = 0.0098
# PC26: Explained Variance = 0.0094
# PC27: Explained Variance = 0.0086
# PC28: Explained Variance = 0.0084
# PC29: Explained Variance = 0.0080
# PC30: Explained Variance = 0.0075
# PC31: Explained Variance = 0.0073
# PC32: Explained Variance = 0.0069
# PC33: Explained Variance = 0.0065
# PC34: Explained Variance = 0.0064
# PC35: Explained Variance = 0.0059
# PC36: Explained Variance = 0.0057
# PC37: Explained Variance = 0.0052
# PC38: Explained Variance = 0.0048
# PC39: Explained Variance = 0.0045
# PC40: Explained Variance = 0.0042
# PC41: Explained Variance = 0.0041
# PC42: Explained Variance = 0.0040
# PC43: Explained Variance = 0.0036
# PC44: Explained Variance = 0.0034
# PC45: Explained Variance = 0.0033
# PC46: Explained Variance = 0.0031
# PC47: Explained Variance = 0.0029
# PC48: Explained Variance = 0.0028
# PC49: Explained Variance = 0.0026
# PC50: Explained Variance = 0.0023
# PC51: Explained Variance = 0.0022
# PC52: Explained Variance = 0.0020
# PC53: Explained Variance = 0.0020
# PC54: Explained Variance = 0.0018
# PC55: Explained Variance = 0.0017
# PC56: Explained Variance = 0.0016
# PC57: Explained Variance = 0.0015
# PC58: Explained Variance = 0.0014
# PC59: Explained Variance = 0.0013
# PC60: Explained Variance = 0.0010
# PC61: Explained Variance = 0.0008
# PC62: Explained Variance = 0.0000
# PC63: Explained Variance = 0.0000
# PC64: Explained Variance = 0.0000

# %% [markdown]
# The explained variance ratios show that the first few principal components (PC1, PC2, PC3) capture the most variance, with PC1 accounting for 12.03%. As we move to higher components, the explained variance decreases, indicating they carry less information about the dataset's overall variance.

# %% [markdown]
# ### Exercise 3

# %%
# Calculate the cumulative variance ratio
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

# Print the cumulative variance ratio
for i, cv in enumerate(cumulative_variance_ratio):
    print(f"PC{i+1}: Cumulative Variance = {cv:.4f}")
# Out:
# PC1: Cumulative Variance = 0.1203
# PC2: Cumulative Variance = 0.2159
# PC3: Cumulative Variance = 0.3004
# PC4: Cumulative Variance = 0.3654
# PC5: Cumulative Variance = 0.4140
# PC6: Cumulative Variance = 0.4561
# PC7: Cumulative Variance = 0.4955
# PC8: Cumulative Variance = 0.5294
# PC9: Cumulative Variance = 0.5594
# PC10: Cumulative Variance = 0.5887
# PC11: Cumulative Variance = 0.6166
# PC12: Cumulative Variance = 0.6423
# PC13: Cumulative Variance = 0.6651
# PC14: Cumulative Variance = 0.6874
# PC15: Cumulative Variance = 0.7090
# PC16: Cumulative Variance = 0.7281
# PC17: Cumulative Variance = 0.7459
# PC18: Cumulative Variance = 0.7623
# PC19: Cumulative Variance = 0.7782
# PC20: Cumulative Variance = 0.7931
# PC21: Cumulative Variance = 0.8066
# PC22: Cumulative Variance = 0.8193
# PC23: Cumulative Variance = 0.8310
# PC24: Cumulative Variance = 0.8416
# PC25: Cumulative Variance = 0.8513
# PC26: Cumulative Variance = 0.8608
# PC27: Cumulative Variance = 0.8694
# PC28: Cumulative Variance = 0.8778
# PC29: Cumulative Variance = 0.8857
# PC30: Cumulative Variance = 0.8932
# PC31: Cumulative Variance = 0.9005
# PC32: Cumulative Variance = 0.9074
# PC33: Cumulative Variance = 0.9139
# PC34: Cumulative Variance = 0.9203
# PC35: Cumulative Variance = 0.9262
# PC36: Cumulative Variance = 0.9320
# PC37: Cumulative Variance = 0.9372
# PC38: Cumulative Variance = 0.9420
# PC39: Cumulative Variance = 0.9465
# PC40: Cumulative Variance = 0.9508
# PC41: Cumulative Variance = 0.9548
# PC42: Cumulative Variance = 0.9588
# PC43: Cumulative Variance = 0.9624
# PC44: Cumulative Variance = 0.9658
# PC45: Cumulative Variance = 0.9691
# PC46: Cumulative Variance = 0.9722
# PC47: Cumulative Variance = 0.9751
# PC48: Cumulative Variance = 0.9778
# PC49: Cumulative Variance = 0.9804
# PC50: Cumulative Variance = 0.9828
# PC51: Cumulative Variance = 0.9849
# PC52: Cumulative Variance = 0.9870
# PC53: Cumulative Variance = 0.9889
# PC54: Cumulative Variance = 0.9908
# PC55: Cumulative Variance = 0.9924
# PC56: Cumulative Variance = 0.9941
# PC57: Cumulative Variance = 0.9955
# PC58: Cumulative Variance = 0.9969
# PC59: Cumulative Variance = 0.9981
# PC60: Cumulative Variance = 0.9992
# PC61: Cumulative Variance = 1.0000
# PC62: Cumulative Variance = 1.0000
# PC63: Cumulative Variance = 1.0000
# PC64: Cumulative Variance = 1.0000

# %% [markdown]
# The results show that each additional principal component captures more variance. For example, PC1 captures 12.03%, and by PC10, 58.87% is captured. All 64 components capture 100% variance. This helps identify how many components are needed to capture a significant portion of the dataset's variance.

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# The cumulative variance ratio shows that to reach at least 85% cumulative variance, 25 components are needed.
#
# We observe that by retaining the first 25 components, we can capture 85.13% of the total variance in the dataset, which significantly reduces the dataset's dimensionality while retaining most of its information.
#
# Using 25 components instead of the original 64 simplifies any downstream models by reducing their feature space, potentially improving model performance and interpretability.
#
# The reduced number of components also makes visualising the data easier, which can provide meaningful insights into class separations or clustering.
#
# Therefore, the ability to capture over 85% of the variance with 25 components makes PCA a viable dimensionality reduction technique for this dataset, preserving most information while simplifying further analyses.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
